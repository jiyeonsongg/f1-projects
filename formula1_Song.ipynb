# %% [markdown]
# # Formula 1 2023
# ### Jiyeon Song

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import re


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'  # Higher resolution figures

# %% [markdown]
# ## 1. EDA

# %%
drivers_df = pd.read_csv("data/drivers.csv").replace(r'\\N', np.nan, regex = True) # all drivers ID with names
constructors_df = pd.read_csv("data/constructors.csv").replace(r'\\N', np.nan, regex = True) # all constructors ID with names
results_df = pd.read_csv("data/results.csv").replace(r'\\N', np.nan, regex = True)

# %% [markdown]
# F1 Drivers 2023
# * Max Verstappen - 1 (Red Bull Racing - 9)
# * Sergio Perez - 11 (Red Bull Racing)
# * Fernando Alonzo - 14 (Aston Martin - 117)
# * Lewis Hamilton - 44 (Mercedes - 131)
# * Carlos Sainz - 55 (Ferrari - 6)
# * George Russell - 63 (Mercedes)
# * Charles Leclerc - 16 (Ferrari)
# * Lance Stroll - 18 (Aston Martin)
# * Lando Norris - 4 (McLaren - 1)
# * Pierre Gasly - 10 (Alpine - 214)
# * Nico Hulkenberg - 27 (Haas F1 Team - 210)
# * Esteban Ocon - 31 (Alpine)
# * Valtteri Bottas - 77 (Alfa Romeo - 51)
# * Oscar Piastri - 81 (McLaren)
# * Zhou Guanyu - 15 (Alfa Romeo)
# * Yuki Tsunoda - 22 (AlphaTauri - 213)
# * Kevin Magnussen - 20 (Haas F1 Team)
# * Alexander Albon - 23 (Williams - 3)
# * Logan Sargeant - 2 (Williams)
# * Nyck De Vries - 21 (AlphaTauri)

# %%
driv_results = drivers_df.merge(results_df, on="driverId")
driv_results
# Out:
#        driverId driverRef number_x code forename   surname         dob  \
# 0             1  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 1             1  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 2             1  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 3             1  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# 4             1  hamilton       44  HAM    Lewis  Hamilton  1985-01-07
# ...         ...       ...      ...  ...      ...       ...         ...
# 25835       855      zhou       24  ZHO   Guanyu      Zhou  1999-05-30
# 25836       855      zhou       24  ZHO   Guanyu      Zhou  1999-05-30
# 25837       855      zhou       24  ZHO   Guanyu      Zhou  1999-05-30
# 25838       855      zhou       24  ZHO   Guanyu      Zhou  1999-05-30
# 25839       856  de_vries       45  DEV     Nyck  de Vries  1995-02-06
#
#       nationality                                          url  resultId  ...  \
# ...
